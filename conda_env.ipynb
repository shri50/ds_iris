# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.3'

# %%
server >> pd version == 2.3.3 
server run on linux >> 90%
linux >> os

# %%
import numpy as np

# %%
np.__version__
# Out:
# '2.2.6'

# %%
dependency management 

DS projects runs on different libraries and 
different systems have different version 

to maintain the similar version across the system we need depedency management (conda)

# %% [markdown]
# # depedency management

# %%
1. conda >> data scientist/ ML 
2. venv >> python developers

# %% [raw]
# Conda is an open-source, cross-platform, language-agnostic package manager and environment management system.
#
# Conda is a powerful command line tool for package and environment management that runs on Windows, macOS, and Linux.

# %% [markdown]
# # Conda

# %% [markdown]
# ## conda env list

# %%
conda env list >> it will provide existing env list 

Command >> conda env list

# %% [markdown]
# # Create env

# %%
command >> conda create --name iris_project

with python version 

command >> conda create -n iris_project_v1 python=3.11

# %% [markdown]
# # env Activate

# %%
command >> conda activate <env_name>

# %% [markdown]
# # env deactivate

# %%
command >> conda deactivate

# %%
import sys
sys.version
# Out:
# '3.12.10 (tags/v3.12.10:0cc8128, Apr  8 2025, 12:21:36) [MSC v.1943 64 bit (AMD64)]'

# %%
dir(sys)
# Out:
# ['__breakpointhook__',
#  '__displayhook__',
#  '__doc__',
#  '__excepthook__',
#  '__interactivehook__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '__stderr__',
#  '__stdin__',
#  '__stdout__',
#  '__unraisablehook__',
#  '_base_executable',
#  '_clear_type_cache',
#  '_current_exceptions',
#  '_current_frames',
#  '_debugmallocstats',
#  '_enablelegacywindowsfsencoding',
#  '_framework',
#  '_getframe',
#  '_getframemodulename',
#  '_git',
#  '_home',
#  '_setprofileallthreads',
#  '_settraceallthreads',
#  '_stdlib_dir',
#  '_vpath',
#  '_xoptions',
#  'activate_stack_trampoline',
#  'addaudithook',
#  'api_version',
#  'argv',
#  'audit',
#  'base_exec_prefix',
#  'base_prefix',
#  'breakpointhook',
#  'builtin_module_names',
#  'byteorder',
#  'call_tracing',
#  'copyright',
#  'deactivate_stack_trampoline',
#  'displayhook',
#  'dllhandle',
#  'dont_write_bytecode',
#  'exc_info',
#  'excepthook',
#  'exception',
#  'exec_prefix',
#  'executable',
# ...
